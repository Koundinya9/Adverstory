# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached streamlit-1.42.0-py2.py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached gensim-4.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# ...
#   Using cached faiss_cpu-1.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.4 kB)
# ...
#   Using cached numpy-2.2.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# ...
#   Using cached google_cloud_vision-3.9.0-py2.py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached langchain_google_vertexai-2.0.13-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached langchain_core-0.3.34-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached langchain-0.3.18-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached google_cloud_aiplatform-1.79.0-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached protobuf-5.29.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# ...
#   Using cached moviepy-2.1.2-py3-none-any.whl.metadata (6.9 kB)
# ...

# %%
# !streamlit run /Users/koundinya/Desktop/AdverstoryWithoutRag/main_with_user.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.26.75.22:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# 2025-02-10 17:39:04.380 Uncaught app execution
# Traceback (most recent call last):
#   File "/Users/koundinya/Desktop/AdverstoryWithoutRag/.venv/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 121, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/Users/koundinya/Desktop/AdverstoryWithoutRag/.venv/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 591, in code_to_exec
#     exec(code, module.__dict__)
#   File "/Users/koundinya/Desktop/AdverstoryWithoutRag/main_with_user.py", line 13, in <module>
#     from rag_processor import RAGProcessor
# ModuleNotFoundError: No module named 'rag_processor'
# ^C
#   Stopping...
# ...
